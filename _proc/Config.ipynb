# %% [raw]
# ---
# description: set dataset path, model_name, validation split, etc.
# output-file: config.html
# title: Define Config file
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Config)
# Out:
# ---
#
# [source](https://github.com/rohitMalhotra07/en_grammar_checker/blob/main/en_grammar_checker/config.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### Config
#
# >      Config ()
#
# *Class to define config for the project*
